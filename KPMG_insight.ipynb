# %%
from bs4 import BeautifulSoup
import requests
# pages = 1
# for page in range(pages):
sources = requests.get('https://www.pwc.co.tz/publications.html').text
soup = BeautifulSoup(sources,'lxml')

soup2 = soup.find_all('div',{"class":"row collectionv2__content"})
print(soup2[0].article)
print(len(soup2))


regular collection__item-heading
# articles = soup2.find_all("article")
# print(articles)


# title = articles.find_all('h4',{"class":"regular collection__item-heading"})
# print(len(title))

# %%
from bs4 import BeautifulSoup
import requests
# pages = 1
# for page in range(pages):
sources = requests.get('https://home.kpmg/ke/en/home/insights.html').text
soup = BeautifulSoup(sources,'lxml')

soup2 = soup.find_all('div',{"class":"grid-tiles col-xs-12 col-md-3"})
print(soup2)
print(len(soup2))



# articles = soup2.find_all("article")
# print(articles)


# title = articles.find_all('h4',{"class":"regular collection__item-heading"})
# print(len(title))
# Out:
# []
# 0

# %%
from requests_html import HTMLSession
import pyppdf.patch_pyppeteer
from bs4 import BeautifulSoup

url = 'https://www.pwc.co.tz/publications.html'

session = HTMLSession()


resp = session.get(url)
resp.html.render()
html = resp.html.html

page_soup = BeautifulSoup(html, 'html.parser')

soup2 = page_soup.find_all('div',{"class":"row collectionv2__content"})
print(soup2[0].article)
print(len(soup2))
# Out:
# ---------------------------------------------------------------------------
# BrowserError                              Traceback (most recent call last)
# <ipython-input-41-94cae52297a8> in <module>()
#       9
#      10 resp = session.get(url)
# ---> 11 resp.html.render()
#      12 html = resp.html.html
#      13
#
# /usr/local/lib/python3.6/dist-packages/requests_html.py in render(self, retries, script, wait, scrolldown, sleep, reload, timeout, keep_page)
#     584         """
#     585
# --> 586         self.browser = self.session.browser  # Automatically create a event loop and browser
#     587         content = None
#     588
#
# /usr/local/lib/python3.6/dist-packages/requests_html.py in browser(self)
#     728             if self.loop.is_running():
#     729                 raise RuntimeError("Cannot use HTMLSession within an existing event loop. Use AsyncHTMLSession instead.")
# --> 730             self._browser = self.loop.run_until_complete(super().browser)
# ...

# %%
# !pip install selenium
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# %%
chrome_options = Options()
chrome_options.add_argument("--incognito")
chrome_options.add_argument("--window-size=1920x1080")

# %%
driver = webdriver.Chrome(chrome_options=chrome_options, executable_path="/content/chromedriver.exe")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: use options instead of chrome_options
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/selenium/webdriver/common/service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# /usr/lib/python3.6/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     728                                 errread, errwrite,
# --> 729                                 restore_signals, start_new_session)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# BrowserError                              Traceback (most recent call last)
# <ipython-input-54-1a0464250a00> in <module>()
#       2 session = HTMLSession()
#       3 r = session.get('https://www.pwc.co.tz/publications.html')
# ----> 4 r.html.render()
#       5
#       6 html = r.html.html
#
# /usr/local/lib/python3.6/dist-packages/requests_html.py in render(self, retries, script, wait, scrolldown, sleep, reload, timeout, keep_page)
#     584         """
#     585
# --> 586         self.browser = self.session.browser  # Automatically create a event loop and browser
#     587         content = None
#     588
#
# /usr/local/lib/python3.6/dist-packages/requests_html.py in browser(self)
#     728             if self.loop.is_running():
#     729                 raise RuntimeError("Cannot use HTMLSession within an existing event loop. Use AsyncHTMLSession instead.")
# ...
